# %% [markdown]
# <a href="https://colab.research.google.com/github/brandon-baek/AUALP_Research/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Comprehensive Exploratory Data Analysis of IMDB Reviews
# This notebook presents a detailed Exploratory Data Analysis (EDA) of the IMDB reviews dataset. The goal is to understand the data's structure, quality, and underlying patterns to inform potential machine learning models for sentiment analysis.

# %%
dataset_path = '/content/drive/MyDrive/HSAIRP/imdb_ratings.csv'

# %%
#@title Prerequisite Libraries
# !pip install umap-learn
# !pip install tsnecuda==3.0.1+cu122 -f https://tsnecuda.isx.ai/tsnecuda_stable.html

from google.colab import drive
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
import seaborn as sns
import matplotlib.pyplot as plt
import umap
from tsnecuda import TSNE as CUDATSNE
from torch.cuda import is_available
import matplotlib.patches as mpatches
from mpl_toolkits.mplot3d import Axes3D
from collections import Counter
from sklearn.manifold import TSNE

drive.mount('/content/drive')
df = pd.read_csv(dataset_path)
# Out:
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.11/dist-packages (0.5.9.post2)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.6 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (1.6.1)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from umap-learn) (4.67.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.11/dist-packages (from pynndescent>=0.5->umap-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.6->umap-learn) (3.6.0)
# Looking in links: https://tsnecuda.isx.ai/tsnecuda_stable.html
# Requirement already satisfied: tsnecuda==3.0.1+cu122 in /usr/local/lib/python3.11/dist-packages (3.0.1+cu122)
# Requirement already satisfied: numpy>=1.14.1 in /usr/local/lib/python3.11/dist-packages (from tsnecuda==3.0.1+cu122) (2.0.2)
# Mounted at /content/drive

# %% [markdown]
# ## 1. Data Quality Assessment and Cleaning
# The first step in any analysis is to assess the quality of the data and perform necessary cleaning operations. This includes handling missing values, duplicates, and ensuring correct data types.

# %% [markdown]
# ### Missing Data and Duplicates
# We begin by loading the data and checking for any missing values or duplicated rows, which can skew our analysis.

# %%
# Initial shape of the dataframe
print(f"Initial shape of the dataframe: {df.shape}")

# Drop rows with missing values
df.dropna(inplace=True)
print(f"Shape after dropping NA values: {df.shape}")

# Drop duplicate rows
df.drop_duplicates(inplace=True)
print(f"Shape after dropping duplicates: {df.shape}")
# Out:
# Initial shape of the dataframe: (50000, 3)
# Shape after dropping NA values: (50000, 3)
# Shape after dropping duplicates: (49586, 3)

# %% [markdown]
# The dataset was cleaned by removing any rows that contained missing values and any rows that were complete duplicates. This ensures that each record in our dataset is unique and complete.

# %% [markdown]
# ### Data Types
# We examine the data types of each column to ensure they are appropriate for the kind of data they hold.

# %%
print(df.dtypes)
# Out:
# Review       object
# Rating        int64
# Sentiment     int64
# dtype: object

# %% [markdown]
# The data types are appropriate for our analysis:
# - **Review**: `object` (string), suitable for text data.
# - **Rating**: `int64`, suitable for numerical ratings from 1 to 10.
# - **Sentiment**: `int64`, suitable for binary sentiment classification (0 or 1).

# %% [markdown]
# ## 2. Feature Engineering
# To enhance our analysis, we can create new features from the existing data. These engineered features can reveal deeper insights.

# %% [markdown]
# ### Creating New Features
# We will create the following new features:
# - `Review_Length`: The total number of characters in the review.
# - `Word_Count`: The total number of words in the review.
# - `Avg_Word_Length`: The average length of words in a review, as a proxy for vocabulary complexity.

# %%
# Engineer new features
df['Review_Length'] = df['Review'].apply(len)
df['Word_Count'] = df['Review'].apply(lambda x: len(x.split()))
df['Avg_Word_Length'] = df['Review'].apply(lambda x: np.mean([len(word) for word in x.split()]) if len(x.split()) > 0 else 0)

print("First 5 rows with new features:")
df.head()
# Out:
# First 5 rows with new features:
#                                               Review  Rating  Sentiment  \
# 0  Kurt Russell's chameleon-like performance, cou...      10          1
# 1  It was extremely low budget(it some scenes it ...       8          1
# 2  James Cagney is best known for his tough chara...       8          1
# 3  Following the brilliant "Goyôkiba" (aka. "Hanz...       8          1
# 4  One of the last classics of the French New Wav...      10          1
#
#    Review_Length  Word_Count  Avg_Word_Length
# 0            632         108         4.861111
# 1           1112         209         4.325359
# 2           2193         394         4.568528
# 3           2553         428         4.967290
# 4           1016         161         5.316770

# %% [markdown]
# ## 3. Descriptive Statistics
# Summary statistics provide a quick overview of the central tendency, dispersion, and shape of the dataset's distribution.

# %% [markdown]
# ### Summary of Key Numerical Features

# %%
# Display summary statistics for numerical columns
df.describe()
# Out:
#              Rating     Sentiment  Review_Length    Word_Count  \
# count  49586.000000  49586.000000   49586.000000  49586.000000
# mean       5.508168      0.501896    1308.798734    231.053221
# std        3.476930      0.500001     988.349664    171.138103
# min        1.000000      0.000000      21.000000      2.000000
# 25%        2.000000      0.000000     699.000000    126.000000
# 50%        7.000000      1.000000     971.000000    173.000000
# 75%        9.000000      1.000000    1590.000000    280.000000
# max       10.000000      1.000000   13704.000000   2470.000000
#
#        Avg_Word_Length
# count     49586.000000
# mean          4.640869
# std           0.341448
# min           1.239865
# 25%           4.418121
# 50%           4.626866
# 75%           4.847341
# max          12.290909

# %% [markdown]
# The summary statistics show a mean rating of approximately 5.5. The `Review_Length` varies significantly, with a mean of around 1300 characters but a standard deviation of nearly 1000, indicating a wide range of review lengths.

# %% [markdown]
# ## 4. Numerical Analysis

# %% [markdown]
# ### Distribution of Ratings and Sentiment
# We'll start by visualizing our target variables to understand their distributions and check for class imbalance.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
fig.suptitle('Distribution of Target Variables', fontsize=16)

# Distribution of Ratings
sns.histplot(df['Rating'], bins=10, ax=ax1, kde=True, color='teal')
ax1.set_title('Distribution of Movie Ratings')
ax1.set_xlabel('Rating (1-10)')
ax1.set_ylabel('Frequency')
ax1.set_xticks(range(1, 11))

# Distribution of Sentiment
sns.countplot(x='Sentiment', data=df, ax=ax2, palette='Set2')
ax2.set_title('Distribution of Sentiment')
ax2.set_xlabel('Sentiment (0: Negative, 1: Positive)')
ax2.set_ylabel('Count')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
# Out:
# /tmp/ipython-input-9-1530428824.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sentiment', data=df, ax=ax2, palette='Set2')

# %% [markdown]
# The visualizations confirm a few key points:
# - The **Rating distribution** is strongly bimodal, with the majority of reviews being either extremely positive (10) or extremely negative (1). This confirms the polarized nature of the dataset.
# - The **Sentiment distribution** is almost perfectly balanced, which is ideal for training a classification model as it avoids bias towards one class.

# %% [markdown]
# ### Review Length Analysis by Rating
# Exploring whether the length of a review has any relationship with the rating given.

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(x='Rating', y='Review_Length', data=df, palette='plasma')
plt.title('Review Length vs. Rating', fontsize=16)
plt.xlabel('Rating')
plt.ylabel('Review Length (characters)')
plt.ylim(0, 5000) # Limiting y-axis for better readability of boxes
plt.show()
# Out:
# /tmp/ipython-input-10-1383014104.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Rating', y='Review_Length', data=df, palette='plasma')

# %% [markdown]
# The box plot shows that while the median review length is fairly consistent across different ratings, moderate ratings such as 4 and 7 have slightly longer reviews on average compared to very low or very high reviews. This suggests that users write more when they have a moderate opinion.

# %% [markdown]
# ### Language Pattern Analysis
# Word clouds provide an intuitive way to see the most frequent words in positive and negative reviews.

# %%
from wordcloud import WordCloud

# Separate the reviews based on sentiment. We also remove words that are similarly frequent on both types of reviews for better analysis
positive_reviews = ' '.join(df[df['Sentiment'] == 1]['Review']).replace('film', '').replace('br', '').replace('movie', '')
negative_reviews = ' '.join(df[df['Sentiment'] == 0]['Review']).replace('film', '').replace('br', '').replace('movie', '')

# Generate word clouds
wordcloud_positive = WordCloud(width=800, height=400, background_color='white', colormap='viridis').generate(positive_reviews)
wordcloud_negative = WordCloud(width=800, height=400, background_color='black', colormap='autumn').generate(negative_reviews)

# Plot the word clouds
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 12))

ax1.imshow(wordcloud_positive, interpolation='bilinear')
ax1.set_title('Word Cloud for Positive Reviews', fontsize=16)
ax1.axis('off')

ax2.imshow(wordcloud_negative, interpolation='bilinear')
ax2.set_title('Word Cloud for Negative Reviews', fontsize=16)
ax2.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# The word clouds clearly differentiate the vocabulary of positive and negative reviews. Positive reviews are characterized by words like "great," "love," "best," and "excellent," while negative reviews frequently use words such as "terrible," "waste," "boring," and "stupid."

# %% [markdown]
# #### N-gram Frequency

# %% [markdown]
# Although single word (Unigrams) frequencies can be beneficial, larger N-grams can hold even deeper meaning. And a simpler view other than the Word Cloud visualization could be more beneficial in finding key details.

# %%
def print_ngram_frequencies(text, max_n=5, top_n_results=100):
    words = text.lower().split()

    ngram_types = {
        1: "Unigrams",
        2: "Bigrams",
        3: "Trigrams",
        4: "Quadgrams",
        5: "Quingrams"
    }

    stop_words = set([
        'the', 'and', 'is', 'a', 'of', 'to', 'in', 'it', 'i', 'that', 'was', 'for', 'on', 'with', 'as',
        'at', 'by', 'this', 'he', 'she', 'they', 'we', 'you', 'or', 'an', 'be', 'has', 'have', 'had',
        'not', 'but', 'from', 'all', 'would', 'can', 'will', 'just', 'about', 'out', 'up', 'down',
        'do', 'did', 'no', 'yes', 'so', 'get', 'if', 'my', 'me', 'your', 'his', 'her', 'its', 'their',
        'which', 'what', 'when', 'where', 'why', 'how', 'than', 'then', 'there', 'who', 'whom', 'here',
        'more', 'most', 'some', 'any', 'such', 'only', 'own', 'same', 'too', 'very', 's', 't', 'can',
        'will', 'don', 'should', 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'couldn',
        'didn', 'doesn', 'hadn', 'hasn', 'haven', 'isn', 'ma', 'mightn', 'mustn', 'needn', 'shan', 'shouldn',
        'wasn', 'weren', 'won', 'wouldn', '\><', 'are', 'one', '/><br'
    ])

    for n in range(1, max_n + 1):
        if len(words) >= n:
            ngrams = [' '.join(words[i:i+n]) for i in range(len(words) - n + 1)]
            filtered_grams = [gram for gram in ngrams if gram not in stop_words]
            print(f'\n- Most Common {ngram_types.get(n, f"{n}-grams")} -')
            print(Counter(filtered_grams).most_common(top_n_results))
        else:
            print(f'\n- Not enough words to form {ngram_types.get(n, f"{n}-grams")} -')

positive_reviews = ' '.join(df[df['Sentiment'] == 1]['Review'])
negative_reviews = ' '.join(df[df['Sentiment'] == 0]['Review'])

print('-- N-gram frequencies for Positive Reviews --')
print_ngram_frequencies(positive_reviews)

print('\n' + '='*50 + '\n')

print('-- N-gram frequencies for Negative Reviews --')
print_ngram_frequencies(negative_reviews)
# Out:
# -- N-gram frequencies for Positive Reviews --
#
# - Most Common Unigrams -
# [('film', 29225), ('movie', 26538), ('like', 16256), ("it's", 15490), ('good', 11756), ('great', 11067), ('see', 10973), ('really', 10290), ('also', 9647), ('story', 9513), ('-', 9159), ('were', 9079), ('even', 9028), ('into', 8592), ('other', 8424), ('much', 8216), ('first', 8090), ('been', 8002), ('time', 7821), ('because', 7677), ('well', 7535), ('best', 7375), ('many', 7287), ('/>the', 7284), ('love', 7130), ('people', 7081), ('him', 6963), ('after', 6891), ('think', 6587), ('two', 6486), ("don't", 6229), ('being', 6199), ('made', 6176), ('make', 6154), ('never', 6143), ('little', 6100), ('could', 5973), ('<br', 5824), ('still', 5790), ('way', 5670), ('seen', 5555), ('does', 5479), ('it.', 5450), ('watch', 5357), ('films', 5300), ('them', 5236), ('characters', 5077), ('character', 5076), ('know', 5030), ('these', 4995), ('show', 4925), ('those', 4879), ('while', 4873), ('life', 4793), ('movies', 4783), ('over', 4661), ('makes', 4607), ('movie.', 4586), ('film.', 4546), ('ever', 4541), ('man', 4479), ('film,', 4430), ('new', 4333), ('find', 4310), ('real', 4252), ('through', 4228), ('back', 4201), ('go', 4116), ('quite', 4049), ('both', 4034), ('young', 4026), ('say', 3964), ('years', 3939), ('lot', 3892), ('scene', 3879), ('every', 3840), ('something', 3816), ('better', 3795), ('off', 3730), ('always', 3729), ('between', 3707), ('may', 3665), ("doesn't", 3627), ('us', 3619), ('acting', 3606), ('scenes', 3589), ('few', 3571), ('movie,', 3506), ('plot', 3499), ('old', 3493), ('another', 3474), ('/>i', 3469), ('before', 3383), ('part', 3342), ('saw', 3333), ('look', 3319), ("i'm", 3314), ('end', 3312), ('going', 3299), ('watching', 3279)]
#
# - Most Common Bigrams -
# [('of the', 40911), ('in the', 24803), ('is a', 15503), ('and the', 13805), ('to the', 12579), ('it is', 10272), ('this movie', 9624), ('the film', 9532), ('to be', 9525), ('one of', 9254), ('this is', 8949), ('in a', 8875), ('on the', 8669), ('with the', 7953), ('for the', 7812), ('of a', 7689), ('this film', 7654), ('/><br />the', 7284), ('at the', 7211), ('it was', 7172), ('the movie', 7108), ('is the', 7015), ('as a', 7004), ('as the', 6764), ('from the', 6067), ('<br /><br', 5824), ('with a', 5721), ('in this', 5479), ('to see', 5052), ('if you', 5012), ('by the', 4924), ('i was', 4882), ('and i', 4595), ('that the', 4494), ('the best', 4441), ('was a', 4384), ('out of', 4339), ('the story', 4284), ('for a', 4234), ('and a', 4216), ('a great', 4198), ('film is', 4174), ('i have', 4152), ('all the', 3976), ('the first', 3938), ('is not', 3916), ('movie is', 3830), ('of his', 3830), ('of this', 3736), ('a lot', 3648), ('the most', 3639), ('there is', 3529), ('/><br />i', 3469), ('a good', 3453), ('a very', 3421), ('he is', 3397), ('the same', 3334), ('have been', 3166), ('about the', 3147), ('on a', 3139), ('there are', 3072), ('i think', 3034), ('that is', 2973), ('but the', 2951), ('is one', 2909), ('and it', 2887), ('but i', 2855), ('some of', 2854), ('a little', 2836), ('but it', 2809), ('to a', 2801), ('has a', 2738), ('lot of', 2611), ('that i', 2572), ('that it', 2511), ('to get', 2503), ('have to', 2493), ("it's a", 2463), ('and his', 2440), ('into the', 2435), ('is an', 2390), ('in his', 2378), ('a few', 2375), ('to make', 2371), ('/><br />this', 2363), ('be a', 2354), ('a bit', 2297), ('was the', 2288), ('they are', 2273), ('the end', 2176), ('that he', 2171), ('the other', 2151), ('have a', 2145), ('is that', 2123), ('want to', 2114), ('who is', 2068), ('the characters', 2065), ('he was', 2050), ('i am', 2047), ('to watch', 2042)]
#
# - Most Common Trigrams -
# [('one of the', 5596), ('this is a', 2653), ('a lot of', 2477), ('is one of', 2359), ('some of the', 1963), ('this movie is', 1953), ('the film is', 1786), ('it is a', 1748), ('of the best', 1579), ('this film is', 1573), ('of the film', 1474), ('as well as', 1348), ('of the most', 1289), ('the fact that', 1250), ('to be a', 1249), ('the movie is', 1208), ('this is the', 1031), ('most of the', 1020), ('of the movie', 1002), ('the end of', 991), ('it was a', 985), ('the rest of', 972), ('there is a', 967), ('this is one', 885), ('the story is', 880), ('out of the', 862), ('rest of the', 839), ('part of the', 838), ('<br /><br />the', 824), ('one of my', 806), ('/><br />this is', 801), ('in the film', 797), ('is a great', 778), ('end of the', 773), ('but it is', 764), ('at the end', 755), ('is a very', 737), ('/><br />the film', 737), ('at the same', 735), ('this movie was', 720), ('a couple of', 717), ('the story of', 705), ('all of the', 668), ('in love with', 667), ('in the movie', 665), ('in this film', 662), ('i have seen', 659), ('if you are', 652), ('in this movie', 647), ('one of those', 643), ('i saw this', 638), ('i have to', 613), ('to see the', 599), ('is not a', 593), ('and it is', 582), ('in order to', 581), ('seems to be', 568), ('to be the', 564), ('the acting is', 562), ('the first time', 560), ('that it is', 551), ('would have been', 548), ('when i was', 542), ('of this film', 538), ('a fan of', 529), ('could have been', 519), ('was one of', 518), ('this is not', 517), ('film is a', 515), ('i have ever', 509), ('it is not', 509), ('because of the', 504), ('to see this', 503), ('that it was', 496), ('the movie was', 494), ('is a good', 488), ('the film was', 488), ('this film was', 482), ('there is no', 482), ('the characters are', 481), ('for the first', 480), ('one of his', 478), ('/><br />if you', 477), ('to say that', 475), ('of the film,', 475), ('a very good', 474), ('a bit of', 466), ('this was a', 465), ('if you like', 463), ('a film that', 462), ('you want to', 460), ('it is the', 457), ('of this movie', 456), ('movie is a', 453), ('is the best', 452), ('<br /><br />i', 450), ('a movie that', 448), ('as good as', 444), ('it would be', 444), ('/><br />this movie', 441)]
#
# - Most Common Quadgrams -
# [('is one of the', 1478), ('one of the best', 1282), ('one of the most', 1048), ('the rest of the', 765), ('this is one of', 733), ('the end of the', 685), ('at the end of', 411), ('of the film is', 369), ('at the same time', 337), ('was one of the', 330), ('/><br />this is a', 327), ('one of my favorite', 298), ('is one of those', 290), ('as well as the', 282), ('! ! ! !', 275), ('as one of the', 268), ('this movie is a', 264), ('this is a great', 262), ('in the middle of', 257), ('one of the greatest', 253), ('the fact that the', 243), ('i thought it was', 239), ('is one of my', 239), ('for the first time', 239), ('the beginning of the', 236), ('/><br />the film is', 235), ('this film is a', 233), ('i saw this movie', 229), ('if you want to', 227), ('a lot of the', 221), ('of the movie is', 219), ('this is a very', 218), ('i have to say', 217), ('rest of the cast', 211), ('be one of the', 209), ('i have ever seen.', 207), ('it is one of', 199), ('to be one of', 192), ('one of the few', 187), ('i first saw this', 186), ('/><br />this movie is', 184), ('turns out to be', 175), ('when it comes to', 173), ('if you are a', 171), ('/><br />the story is', 171), ('a bit of a', 171), ('some of the best', 171), ('the story of a', 170), ('/><br />all in all,', 170), ('this is not a', 169), ('falls in love with', 168), ('the first time i', 165), ('it would have been', 165), ('the film is a', 163), ('the best of the', 163), ('at the same time.', 162), ('is a film that', 161), ('on the edge of', 158), ('on the other hand,', 156), ('i would like to', 154), ('/><br />this film is', 153), ('this is a film', 153), ('with a lot of', 150), ('i saw this film', 146), ('a lot of people', 146), ('recommend this movie to', 146), ('have to say that', 145), ('one of the better', 145), ('this is a movie', 144), ('the fact that it', 143), ('a great deal of', 141), ('/><br />the movie is', 140), ('a big fan of', 140), ('at the same time,', 140), ('one of the funniest', 139), ('is a movie that', 136), ('a must see for', 135), ('in a way that', 134), ('of this film is', 133), ('this is the best', 133), ('of the best movies', 130), ('when i first saw', 130), ('is the story of', 130), ('when i was a', 129), ('tells the story of', 129), ('to do with the', 129), ('at the beginning of', 128), ('by the end of', 127), ('and some of the', 127), ('i highly recommend this', 127), ("it's one of the", 125), ('the middle of the', 125), ('as good as the', 124), ('i have ever seen', 124), ('of the best films', 123), ("if you haven't seen", 123), ('/><br />one of the', 123), ('one of those movies', 123), ('i have seen in', 123), ("i don't want to", 123)]
#
# - Most Common Quingrams -
# [('is one of the best', 443), ('this is one of the', 422), ('is one of the most', 301), ('at the end of the', 282), ('! ! ! ! !', 273), ('the rest of the cast', 176), ('to be one of the', 137), ('one of the best movies', 127), ('it is one of the', 119), ('this is one of those', 109), ('one of the best films', 108), ('by the end of the', 108), ('i have to say that', 102), ('at the beginning of the', 101), ('the end of the film', 98), ('is one of my favorite', 97), ('and the rest of the', 97), ('in the middle of the', 96), ('the first time i saw', 92), ('this is one of my', 84), ('is one of those movies', 80), ('is one of the few', 79), ('but at the same time', 79), ('if you are looking for', 77), ('if you want to see', 77), ('was one of the best', 77), ('the end of the movie', 75), ('you are a fan of', 75), ('one of the best of', 73), ('one of those movies that', 73), ('and at the same time', 71), ('for the first time in', 71), ('there are a lot of', 69), ('the first half of the', 68), ('for the rest of the', 68), ('i first saw this movie', 68), ('the end of the film,', 67), ('this was one of the', 67), ('the rest of the film', 66), ('has to be one of', 65), ('there is a lot of', 65), ('rest of the cast is', 65), ('if you are a fan', 65), ('one of those films that', 60), ('is one of the greatest', 59), ('this is a movie that', 59), ('it was one of the', 59), ('you are looking for a', 58), ('is a must see for', 58), ('turns out to be a', 57), ('on the edge of my', 57), ('i thought it was a', 56), ('is one of those films', 56), ('one of the most beautiful', 56), ('i have seen in a', 56), ('this is a film that', 55), ('this movie is one of', 55), ('i have to admit that', 54), ('be one of the most', 54), ('for those of you who', 54), ('one of my all time', 54), ('is one of the better', 54), ('is the story of a', 53), ('the rest of the movie', 53), ("if you're a fan of", 53), ('i would love to see', 53), ('in the middle of a', 51), ('/><br />this is one of', 51), ('on the edge of your', 51), ('movie is one of the', 50), ('be one of the best', 50), ('is one of the funniest', 50), ('has nothing to do with', 50), ('i first saw this film', 49), ('recommend this movie to anyone', 48), ('the other side of the', 48), ('when i first saw this', 46), ('this is the kind of', 46), ('this movie when i was', 46), ('i had never heard of', 45), ('i fell in love with', 44), ('this film is one of', 44), ('film is one of the', 44), ('this is a very good', 44), ('was one of the most', 44), ('at the start of the', 43), ('as one of the best', 43), ('based on a true story', 43), ('the beginning of the film', 43), ('/><br />the rest of the', 42), ('i found it to be', 42), ("it's one of the best", 42), ('recommend it to anyone who', 42), ('of the best of the', 41), ('this is a great movie', 41), ('that this is one of', 41), ('i was lucky enough to', 41), ('you on the edge of', 41), ('as one of the most', 41), ('it was going to be', 41)]
#
# ==================================================
#
# -- N-gram frequencies for Negative Reviews --
#
# - Most Common Unigrams -
# [('movie', 34441), ('film', 25414), ('like', 20684), ("it's", 15464), ('even', 14437), ('good', 11519), ('were', 11444), ('really', 11343), ('bad', 10495), ('been', 9744), ('see', 9725), ("don't", 9362), ('because', 9307), ('-', 8903), ('much', 8896), ('into', 8807), ('could', 8803), ('make', 8737), ('other', 7816), ('people', 7812), ('time', 7697), ('/>the', 7308), ('made', 7243), ('first', 7218), ('story', 7168), ('after', 6953), ('think', 6605), ('being', 6380), ('never', 6368), ('<br', 6098), ('movie.', 6072), ('watch', 5998), ('also', 5976), ('plot', 5878), ('acting', 5696), ('know', 5660), ('it.', 5624), ('them', 5612), ('little', 5609), ('ever', 5601), ('two', 5587), ('way', 5578), ('movies', 5515), ('him', 5504), ('many', 5489), ('characters', 5403), ('these', 5250), ('off', 5215), ('character', 5195), ('does', 5193), ('nothing', 5192), ('better', 5173), ("didn't", 5119), ('seen', 4961), ('over', 4930), ("doesn't", 4918), ("i'm", 4876), ('something', 4861), ('say', 4786), ('watching', 4784), ('actually', 4643), ('go', 4615), ('thing', 4519), ('movie,', 4490), ('worst', 4366), ('show', 4336), ('through', 4321), ('film.', 4303), ('going', 4300), ('scene', 4279), ('great', 4278), ('while', 4225), ('films', 4209), ('scenes', 4147), ('those', 4120), ('&', 4097), ('few', 4075), ('well', 4060), ('pretty', 4049), ("can't", 4030), ('look', 4027), ('want', 3975), ('/>i', 3965), ('still', 3914), ('every', 3888), ('seems', 3837), ('another', 3822), ("that's", 3744), ('real', 3717), ('got', 3690), ('back', 3640), ('film,', 3614), ('find', 3612), ('end', 3602), ('actors', 3593), ('give', 3555), ('love', 3554), ('makes', 3536), ('least', 3485), ("isn't", 3457)]
#
# - Most Common Bigrams -
# [('of the', 34730), ('in the', 23419), ('this movie', 12638), ('to be', 12586), ('and the', 11553), ('to the', 10559), ('is a', 10176), ('the movie', 9273), ('it was', 8397), ('on the', 8350), ('in a', 8115), ('the film', 8042), ('of a', 7589), ('for the', 7565), ('this is', 7477), ('this film', 7365), ('/><br />the', 7308), ('with the', 7130), ('it is', 7128), ('one of', 6348), ('is the', 6111), ('<br /><br', 6098), ('in this', 6053), ('at the', 6040), ('as a', 6000), ('with a', 5936), ('out of', 5520), ('from the', 5494), ('that the', 5250), ('if you', 5238), ('have been', 5103), ('i was', 5046), ('movie is', 4869), ('to see', 4643), ('for a', 4580), ('was a', 4549), ('i have', 4384), ('by the', 4370), ('there is', 4331), ('the first', 4281), ('of this', 4231), ('as the', 4157), ('and i', 4064), ('/><br />i', 3965), ('all the', 3928), ('to make', 3852), ('the only', 3831), ('and a', 3818), ('is not', 3794), ('a good', 3585), ('the worst', 3481), ('film is', 3460), ('the story', 3400), ('but the', 3366), ('the same', 3357), ('there are', 3326), ('on a', 3153), ('but i', 3128), ('a lot', 3101), ('be a', 3094), ('would have', 3076), ('like a', 3052), ('that i', 3006), ('the most', 2982), ('about the', 2976), ('was the', 2922), ('a few', 2892), ('want to', 2864), ('that it', 2861), ("i don't", 2821), ('a movie', 2819), ('at least', 2798), ('to a', 2793), ('have to', 2754), ('is that', 2696), ('but it', 2656), ('the plot', 2644), ('that is', 2630), ('to get', 2594), ('kind of', 2575), ('movie was', 2571), ('trying to', 2555), ('would be', 2544), ('the acting', 2498), ('could have', 2493), ('they are', 2482), ('the whole', 2478), ('to watch', 2461), ('to do', 2438), ('i am', 2384), ('to have', 2383), ('into the', 2367), ('i think', 2350), ('of his', 2334), ('the characters', 2329), ('some of', 2320), ('the end', 2311), ('this was', 2289), ('have a', 2270), ('lot of', 2270)]
#
# - Most Common Trigrams -
# [('one of the', 3829), ('this movie is', 2552), ('a lot of', 2115), ('to be a', 1792), ('some of the', 1655), ('of the movie', 1535), ('this is a', 1532), ('the fact that', 1483), ('this movie was', 1460), ('this film is', 1456), ('the movie is', 1454), ('the rest of', 1420), ('the film is', 1366), ('of the film', 1349), ('most of the', 1262), ('rest of the', 1192), ('supposed to be', 1176), ('is one of', 1147), ('could have been', 1145), ('would have been', 1056), ('i have ever', 1054), ('of the worst', 1053), ('the acting is', 1022), ('out of the', 1010), ('this is the', 991), ('it was a', 950), ('in this movie', 949), ('there is no', 946), ('a couple of', 944), ('the end of', 938), ('you want to', 921), ('in the movie', 902), ('to make a', 901), ('there is a', 877), ('a bunch of', 871), ('it is a', 846), ('in the first', 828), ('part of the', 817), ('the movie was', 792), ('<br /><br />the', 788), ('if you want', 781), ('end of the', 773), ('to do with', 772), ('in the film', 771), ('seems to be', 762), ('to be the', 755), ('at the end', 749), ('the story is', 739), ('of the most', 738), ('have been a', 712), ('one of those', 707), ('of this movie', 679), ('if you are', 677), ('the plot is', 660), ('in this film', 645), ('i have to', 642), ('this film was', 628), ('that it was', 619), ('the only thing', 605), ('it would be', 592), ('want to see', 584), ("i don't know", 582), ('to see this', 581), ('in order to', 580), ('the acting was', 576), ('as well as', 574), ('a waste of', 567), ('all of the', 565), ('the characters are', 563), ('i have seen', 560), ('is supposed to', 557), ('any of the', 555), ('the worst movie', 555), ('of this film', 553), ('is not a', 551), ('this is not', 549), ('/><br />if you', 541), ('of the characters', 539), ('the film was', 534), ('i would have', 531), ('this is one', 531), ('/><br />this is', 517), ("i don't think", 510), ('a group of', 505), ('should have been', 503), ('/><br />this movie', 502), ('to see a', 502), ('to watch this', 500), ('that this movie', 497), ('to see the', 494), ('this was a', 493), ('a fan of', 489), ('i saw this', 483), ('/><br />the film', 470), ('a bit of', 470), ('movie is a', 468), ('going to be', 467), ('that it is', 467), ('is that the', 464), ('has to be', 457)]
#
# - Most Common Quadgrams -
# [('the rest of the', 1113), ('one of the worst', 834), ('is one of the', 730), ('the end of the', 674), ('one of the most', 557), ('if you want to', 522), ('i have ever seen.', 427), ('this is one of', 406), ('is supposed to be', 390), ('in the middle of', 377), ('at the end of', 370), ('of the movie is', 332), ('you want to see', 315), ('was one of the', 301), ('of the worst movies', 299), ('to do with the', 297), ('this movie is a', 292), ('supposed to be a', 290), ('the fact that the', 287), ('of the film is', 279), ('nothing to do with', 268), ('it would have been', 246), ('could have been a', 243), ('was supposed to be', 239), ('movie i have ever', 237), ('is one of those', 231), ('be one of the', 228), ('the beginning of the', 221), ('the only thing that', 219), ('it could have been', 218), ('i have ever seen', 212), ('the middle of the', 210), ('to be one of', 206), ('/><br />this movie is', 204), ('i have to say', 200), ('when it comes to', 196), ('a big fan of', 196), ('the worst movie i', 193), ('a lot of the', 193), ('i thought it was', 190), ("don't waste your time", 188), ('want to see a', 187), ('worst movie i have', 187), ('rest of the movie', 183), ('was going to be', 180), ('rest of the cast', 179), ('on the other hand,', 174), ('would have been a', 172), ('the only reason i', 171), ('turns out to be', 171), ('this is not a', 167), ('as one of the', 166), ('of the worst films', 164), ('one of the best', 163), ('the fact that it', 163), ('in this movie is', 162), ('the special effects are', 161), ('i saw this movie', 158), ('this is the worst', 158), ('hour and a half', 158), ('movies i have ever', 154), ('/><br />this is a', 153), ('there are a few', 153), ('there are so many', 150), ('that this movie is', 149), ('this film is a', 149), ('an hour and a', 149), ('by the end of', 148), ('at the same time', 147), ('that this is a', 146), ('for the rest of', 144), ('if you are a', 144), ('this movie is not', 141), ('for the sake of', 138), ('the only good thing', 138), ('this movie is the', 137), ('as well as the', 137), ('a bit of a', 135), ('this movie is so', 135), ('/><br />the plot is', 134), ('if you want a', 134), ("i don't know what", 134), ('of the movie was', 133), ('end of the movie', 132), ('this movie was a', 132), ('of this movie is', 132), ('/><br />as for the', 130), ('/><br />the movie is', 130), ('/><br />if you want', 130), ('/><br />the acting is', 130), ('nothing more than a', 129), ('a complete waste of', 129), ('rest of the film', 128), ('some of the worst', 128), ('about this movie is', 127), ('a huge fan of', 127), ('in front of the', 126), ('it would be a', 125), ('this could have been', 125), ('has nothing to do', 123)]
#
# - Most Common Quingrams -
# [('one of the worst movies', 286), ('at the end of the', 274), ('this is one of the', 250), ('is one of the worst', 232), ('if you want to see', 226), ('in the middle of the', 177), ('to be one of the', 169), ('the worst movie i have', 166), ('the rest of the cast', 161), ('the rest of the movie', 159), ('worst movie i have ever', 158), ('one of the worst films', 154), ('nothing to do with the', 145), ('you want to see a', 140), ('is one of the most', 139), ('the end of the movie', 122), ('the rest of the film', 116), ('has nothing to do with', 114), ('of the worst movies i', 114), ('by the end of the', 112), ('is supposed to be a', 112), ('the worst movies i have', 110), ('this is one of those', 105), ('worst movies i have ever', 104), ('at the beginning of the', 102), ('and the rest of the', 98), ('an hour and a half', 97), ('there are a lot of', 97), ('movie i have ever seen.', 95), ('be one of the worst', 94), ('has to be one of', 90), ('/><br />if you want to', 88), ('movies i have ever seen.', 86), ('the worst film i have', 85), ('if you are looking for', 84), ('i have ever seen in', 84), ("the worst movie i've ever", 83), ('the end of the movie,', 83), ('for the rest of the', 82), ('the end of the film', 82), ("of the worst movies i've", 80), ('i was looking forward to', 79), ('the best part of the', 79), ('the only good thing about', 76), ('the first half of the', 75), ('hour and a half of', 75), ('this is the kind of', 74), ('it was going to be', 73), ('in the middle of a', 70), ('this was one of the', 69), ('worst film i have ever', 69), ('do yourself a favor and', 69), ('i have to say that', 68), ('was supposed to be a', 68), ('i have ever seen. i', 67), ('with the rest of the', 66), ('this is the worst movie', 66), ('is by far the worst', 66), ('if you want to watch', 66), ('was one of the worst', 65), ('rest of the movie is', 63), ('is one of those movies', 62), ('of the worst films i', 62), ('the worst films i have', 62), ('i have ever seen. the', 62), ('have ever seen in my', 62), ('this could have been a', 61), ("if you're looking for a", 61), ('you are looking for a', 61), ("the worst movies i've ever", 61), ('could have been so much', 60), ('waste your time on this', 60), ('it was supposed to be', 58), ('it was one of the', 57), ('was one of the most', 57), ('one of those movies that', 56), ('only good thing about this', 56), ('worst films i have ever', 55), ('turns out to be a', 55), ("i'm a big fan of", 55), ('the end of the film,', 55), ('waste your time with this', 55), ('movie i have ever seen', 54), ('films i have ever seen.', 53), ('had nothing to do with', 53), ('of the rest of the', 53), ('there is a lot of', 53), ('i went to see this', 52), ('of the worst movies ever', 52), ('this is supposed to be', 52), ('a waste of time and', 52), ("if you're a fan of", 52), ('it could have been a', 51), ('you want to watch a', 51), ('thing about this movie is', 51), ('was going to be a', 50), ('/><br />the rest of the', 50), ('this movie could have been', 49), ('is nothing more than a', 49), ('you are a fan of', 49)]

# %% [markdown]
# #### Exploring Vocabulary Complexity
# We can use our engineered `Avg_Word_Length` feature to see if vocabulary complexity differs by rating.

# %%
plt.figure(figsize=(12, 7))
sns.lineplot(x='Rating', y='Avg_Word_Length', data=df, marker='o', color='crimson')
plt.title('Average Word Length vs. Rating', fontsize=16)
plt.xlabel('Rating')
plt.ylabel('Average Word Length')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# There appears to be a subtle upside down "U-shaped" relationship. Reviews with very low (1) or very high (10) ratings tend to use slightly shorter words on average. This might suggest that less effort and weaker vocabulary are employed when expressing strong, polarized opinions. However, higher ratings tend to have slightly longer word length averages than lower ratings.

# %% [markdown]
# ## 5. Advanced Analysis: Embeddings and Correlations

# %% [markdown]
# When extracting the review embeddings and reducing the dimensionality, the model may take awhile. In Google Colab, I reccomend using the T4 GPU Runtime for faster results. Adjust the batch size depending on your device:
#
# - 1024 - Best for T4 GPU
# - 64 - Best for CPU

# %%
batch_size = 1024

if is_available():
    device = 'cuda'
else:
    device = 'cpu'

embedding_model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

review_embeddings = embedding_model.encode(list(df['Review']), batch_size=batch_size, show_progress_bar=True, device=device)

umap_d2_reducer = umap.UMAP(n_components=2, random_state=42)
umap_d2_reduced_X = umap_d2_reducer.fit_transform(review_embeddings, device=device)
umap_d3_reducer = umap.UMAP(n_components=3, random_state=42)
umap_d3_reduced_X = umap_d3_reducer.fit_transform(review_embeddings, device=device)

tsne_d2_reducer = CUDATSNE(n_components=2)
tsne_d2_reduced_X = tsne_d2_reducer.fit_transform(review_embeddings)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/49 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %% [markdown]
# ### Visualizing Review Embeddings with UMAP and t-SNE
# We can visualize the high-dimensional sentence embeddings in 2D & 3D using UMAP & t-SNE to see if reviews with similar sentiments cluster together.

# %%
sentiment_colors = df['Sentiment'].map({1: 'dodgerblue', 0: 'tomato'})

# --- 2D UMAP Projection ---
plt.figure(figsize=(12, 10))
plt.scatter(umap_d2_reduced_X[:, 0], umap_d2_reduced_X[:, 1], c=sentiment_colors, s=1, alpha=0.6)

plt.title('UMAP Projection of IMDB Review Embeddings by Sentiment (2D)', fontsize=16)
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')

# Create a custom legend
red_patch = mpatches.Patch(color='tomato', label='Negative Sentiment')
blue_patch = mpatches.Patch(color='dodgerblue', label='Positive Sentiment')
plt.legend(handles=[red_patch, blue_patch])

plt.show()

# --- 3D UMAP Projection ---
fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(umap_d3_reduced_X[:, 0], umap_d3_reduced_X[:, 1], umap_d3_reduced_X[:, 2], c=sentiment_colors, s=1, alpha=0.6)

ax.set_title('UMAP Projection of IMDB Review Embeddings by Sentiment (3D)', fontsize=16)
ax.set_xlabel('UMAP Dimension 1')
ax.set_ylabel('UMAP Dimension 2')
ax.set_zlabel('UMAP Dimension 3')

# Create a custom legend for 3D plot
ax.legend(handles=[red_patch, blue_patch])

plt.show()

# %% [markdown]
# The UMAP visualization is highly informative. It clearly shows two distinct clusters, one for positive sentiment (blue) and one for negative sentiment (red). This indicates that the sentence embeddings effectively capture the semantic meaning of the reviews, making them an excellent feature for a classification model.

# %%
sentiment_colors = df['Sentiment'].map({1: 'dodgerblue', 0: 'tomato'})

# --- 2D t-SNE Projection ---
plt.figure(figsize=(12, 10))
plt.scatter(tsne_d2_reduced_X[:, 0], tsne_d2_reduced_X[:, 1], c=sentiment_colors, s=1, alpha=0.6)

plt.title('t-SNE Projection of IMDB Review Embeddings by Sentiment (2D)', fontsize=16)
plt.xlabel('t-SNE Dimension 1')
plt.ylabel('t-SNE Dimension 2')

# Create a custom legend
red_patch = mpatches.Patch(color='tomato', label='Negative Sentiment')
blue_patch = mpatches.Patch(color='dodgerblue', label='Positive Sentiment')
plt.legend(handles=[red_patch, blue_patch])

plt.show()

# %% [markdown]
# Due to the computationally expensive nature of t-SNE, it requires a GPU. So we utilize the tsnecuda library to take advantage of a GPU. However, the tsnecuda library does not support dimensionality reduction into 3 dimensions, we are only left with a 2 dimensional visual. But even so, the t-SNE reduction shows far clearer clusters than UMAP. There are strong clusters for negative sentiments and postive sentiment, however positive sentiments seem to have slightly weaker clusters.

# %% [markdown]
# ### Feature Correlation Heatmap
# A heatmap of the correlation matrix helps us understand the linear relationships between our numerical features.

# %%
# Select numerical columns for correlation matrix
numerical_cols = ['Rating', 'Sentiment', 'Review_Length', 'Word_Count', 'Avg_Word_Length']
corr_matrix = df[numerical_cols]+review_embeddings.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Correlation Matrix of Numerical Features', fontsize=16)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-17-3142580071.py in <cell line: 0>()
#       1 # Select numerical columns for correlation matrix
#       2 numerical_cols = ['Rating', 'Sentiment', 'Review_Length', 'Word_Count', 'Avg_Word_Length']
# ----> 3 corr_matrix = df[numerical_cols]+review_embeddings.corr()
#       4
#       5 # Plot the heatmap
#
# AttributeError: 'numpy.ndarray' object has no attribute 'corr'
